# %%
import os
import sys
import json
from pathlib import Path
from typing import List

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.utils import to_categorical

import nibabel as nib
import SimpleITK as sitk
from scipy.ndimage import rotate as scipy_rotate

from PIL import Image, ImageOps, ImageFilter
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report


tf.keras.mixed_precision.set_global_policy('mixed_bfloat16')
# Out:
# 2025-12-17 00:53:09.360592: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-17 00:53:09.389911: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-17 00:53:10.006654: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
def double_conv_block_3d(x, n_filters, kernel_size=3):
    x = layers.Conv3D(n_filters, kernel_size, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv3D(n_filters, kernel_size, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    return x


def downsample_block_3d(x, n_filters, dropout_rate=0.3):
    f = double_conv_block_3d(x, n_filters)
    p = layers.MaxPool3D(pool_size=(2, 2, 2))(f)
    p = layers.Dropout(dropout_rate)(p)
    return f, p


def upsample_block_3d(x, skip_features, n_filters, dropout_rate=0.5):
    x = layers.Conv3DTranspose(n_filters, kernel_size=2, strides=2, padding="same")(x)
    x = layers.concatenate([x, skip_features])
    x = layers.Dropout(dropout_rate)(x)
    x = double_conv_block_3d(x, n_filters)
    return x


def build_3d_unet(input_shape=(128, 128, 128, 1), num_classes=3, base_filters=32):
    inputs = layers.Input(shape=input_shape)
    
    f1, p1 = downsample_block_3d(inputs, base_filters)        
    f2, p2 = downsample_block_3d(p1, base_filters * 2)        
    f3, p3 = downsample_block_3d(p2, base_filters * 4)        
    f4, p4 = downsample_block_3d(p3, base_filters * 8)
    
    bottleneck = double_conv_block_3d(p4, base_filters * 16)  
    
    u1 = upsample_block_3d(bottleneck, f4, base_filters * 8)  
    u2 = upsample_block_3d(u1, f3, base_filters * 4)         
    u3 = upsample_block_3d(u2, f2, base_filters * 2)         
    u4 = upsample_block_3d(u3, f1, base_filters)            
    

    outputs = layers.Conv3D(num_classes, kernel_size=1, padding="same", activation="softmax")(u4)
    
    model = models.Model(inputs, outputs, name="3D-UNet")
    return model

# %%
DATA_DIR = 'preprocessed_patches_v2' 
NUM_CLASSES = 3
SEED = 42

TRAIN_RATIO = 0.70
VAL_RATIO = 0.15
TEST_RATIO = 0.15

all_files = sorted([os.path.join(DATA_DIR, f) for f in os.listdir(DATA_DIR) if f.endswith('.npz')])

np.random.seed(SEED)
indices = np.random.permutation(len(all_files))

train_end = int(len(all_files) * TRAIN_RATIO)
val_end = train_end + int(len(all_files) * VAL_RATIO)

train_files = [all_files[i] for i in indices[:train_end]]
val_files = [all_files[i] for i in indices[train_end:val_end]]
test_files = [all_files[i] for i in indices[val_end:]]

# %%
def augment_rotation_3d(volume, segmentation, max_angle=30):
    angle_x = np.random.uniform(-max_angle, max_angle)
    angle_y = np.random.uniform(-max_angle, max_angle)
    angle_z = np.random.uniform(-max_angle, max_angle)
    
    vol_rotated = scipy_rotate(volume, angle_z, axes=(0, 1), reshape=False, order=1, mode='constant', cval=0)
    vol_rotated = scipy_rotate(vol_rotated, angle_y, axes=(0, 2), reshape=False, order=1, mode='constant', cval=0)
    vol_rotated = scipy_rotate(vol_rotated, angle_x, axes=(1, 2), reshape=False, order=1, mode='constant', cval=0)
    
    seg_rotated = scipy_rotate(segmentation, angle_z, axes=(0, 1), reshape=False, order=0, mode='constant', cval=0)
    seg_rotated = scipy_rotate(seg_rotated, angle_y, axes=(0, 2), reshape=False, order=0, mode='constant', cval=0)
    seg_rotated = scipy_rotate(seg_rotated, angle_x, axes=(1, 2), reshape=False, order=0, mode='constant', cval=0)
    
    return vol_rotated, seg_rotated


def augment_gamma(volume, gamma_range=(0.7, 1.5)):
    gamma = np.random.uniform(gamma_range[0], gamma_range[1])
    return np.power(np.clip(volume, 0, 1), gamma)


def augment_gaussian_noise(volume, sigma_range=(0, 0.05)):
    sigma = np.random.uniform(sigma_range[0], sigma_range[1])
    noise = np.random.normal(0, sigma, volume.shape)
    return np.clip(volume + noise, 0, 1)


def augment_brightness(volume, delta_range=(-0.1, 0.1)):
    delta = np.random.uniform(delta_range[0], delta_range[1])
    return np.clip(volume + delta, 0, 1)


def apply_augmentation(volume, segmentation, augment=True):
    if not augment:
        return volume, segmentation
    if np.random.random() < 0.5:
        volume, segmentation = augment_rotation_3d(volume, segmentation, max_angle=30)
    # Intensity augmentations
    if np.random.random() < 0.3:
        volume = augment_gamma(volume, gamma_range=(0.7, 1.5))
    
    if np.random.random() < 0.1:
        volume = augment_gaussian_noise(volume, sigma_range=(0, 0.05))
    
    if np.random.random() < 0.3:
        volume = augment_brightness(volume, delta_range=(-0.1, 0.1))
    
    return volume, segmentation


class VolumeGenerator(tf.keras.utils.Sequence):
    
    def __init__(self, files, batch_size=2, num_classes=3, shuffle=True, augment=False):
        self.files = files
        self.batch_size = batch_size
        self.num_classes = num_classes
        self.shuffle = shuffle
        self.augment = augment
        
        self.batch_indices = []
        for file_idx, filepath in enumerate(files):
            data = np.load(filepath)
            n_patches = len(data['patches'])
            for start in range(0, n_patches, batch_size):
                self.batch_indices.append((file_idx, start))
        
        self.on_epoch_end()
    
    def __len__(self):
        return len(self.batch_indices)
    
    def __getitem__(self, idx):
        file_idx, patch_start = self.batch_indices[self.indices[idx]]
        data = np.load(self.files[file_idx])
        
        patch_end = patch_start + self.batch_size
        
        x = data['patches'][patch_start:patch_end].astype(np.float32) / 255.0
        y = data['segmentations'][patch_start:patch_end]
        
        if self.augment:
            x_aug = []
            y_aug = []
            for i in range(len(x)):
                vol_aug, seg_aug = apply_augmentation(x[i], y[i], augment=True)
                x_aug.append(vol_aug)
                y_aug.append(seg_aug)
            x = np.array(x_aug, dtype=np.float32)
            y = np.array(y_aug)
        
        x = x[..., np.newaxis]
        y = to_categorical(y, num_classes=self.num_classes)
        
        return x, y
    
    def on_epoch_end(self):
        self.indices = np.arange(len(self.batch_indices))
        if self.shuffle:
            np.random.shuffle(self.indices)


BATCH_SIZE = 4

train_gen = VolumeGenerator(train_files, batch_size=BATCH_SIZE, num_classes=NUM_CLASSES, shuffle=True, augment=True)
val_gen = VolumeGenerator(val_files, batch_size=BATCH_SIZE, num_classes=NUM_CLASSES, shuffle=False, augment=False)
test_gen = VolumeGenerator(test_files, batch_size=BATCH_SIZE, num_classes=NUM_CLASSES, shuffle=False, augment=False)

# %%
CLASS_WEIGHTS = [0.1, 0.8, 20.0]


def dice_coefficient_per_class(y_true, y_pred, class_idx, smooth=1e-6):
    """Dice coefficient for a single class."""
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_true_c = y_true[..., class_idx]
    y_pred_c = y_pred[..., class_idx]
    y_true_f = tf.keras.backend.flatten(y_true_c)
    y_pred_f = tf.keras.backend.flatten(y_pred_c)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)


def weighted_dice_loss(y_true, y_pred):
    """Weighted dice loss - higher weight for tumor class."""
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    total_loss = 0.0
    for class_idx, weight in enumerate(CLASS_WEIGHTS):
        dice = dice_coefficient_per_class(y_true, y_pred, class_idx)
        total_loss += weight * (1 - dice)
    
    return total_loss / sum(CLASS_WEIGHTS)

def dice_coefficient(y_true, y_pred):
    """Overall dice coefficient."""
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1e-6) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + 1e-6)


def dice_liver(y_true, y_pred):
    """Dice coefficient for liver (class 1)."""
    return dice_coefficient_per_class(y_true, y_pred, 1)


def dice_tumor(y_true, y_pred):
    """Dice coefficient for tumor (class 2)."""
    return dice_coefficient_per_class(y_true, y_pred, 2)


print("Loss function: Weighted Dice Loss")
print(f"Class weights: Background={CLASS_WEIGHTS[0]}, Liver={CLASS_WEIGHTS[1]}, Tumor={CLASS_WEIGHTS[2]}")
# Out:
# Loss function: Weighted Dice Loss
# Class weights: Background=0.1, Liver=0.8, Tumor=20.0

# %%
model = build_3d_unet(input_shape=(128, 128, 128, 1), num_classes=NUM_CLASSES, base_filters=24)

# Load pretrained weights
PRETRAINED_PATH = 'checkpoints/best_model_v2_24_final.keras'
print(f"Loading pretrained weights from {PRETRAINED_PATH}...")
model.load_weights(PRETRAINED_PATH)
print("Weights loaded successfully!")

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=weighted_dice_loss,
    metrics=[dice_coefficient, dice_liver, dice_tumor]
)

model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765950811.034270    6356 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9102 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Loading pretrained weights from checkpoints/best_model_v2_24_final.keras...
# Weights loaded successfully!
# Model: "3D-UNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 128, 1)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d (Conv3D)     │ (None, 128, 128,  │        672 │ input_layer[0][0] │
# │                     │ 128, 24)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │         96 │ conv3d[0][0]      │
# │ (BatchNormalizatio… │ 128, 24)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128, 24)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_1 (Conv3D)   │ (None, 128, 128,  │     15,576 │ activation[0][0]  │
# │                     │ 128, 24)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         96 │ conv3d_1[0][0]    │
# │ (BatchNormalizatio… │ 128, 24)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128, 24)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d       │ (None, 64, 64,    │          0 │ activation_1[0][… │
# │ (MaxPooling3D)      │ 64, 24)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64, 64,    │          0 │ max_pooling3d[0]… │
# │                     │ 64, 24)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_2 (Conv3D)   │ (None, 64, 64,    │     31,152 │ dropout[0][0]     │
# │                     │ 64, 48)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv3d_2[0][0]    │
# │ (BatchNormalizatio… │ 64, 48)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64, 48)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_3 (Conv3D)   │ (None, 64, 64,    │     62,256 │ activation_2[0][… │
# │                     │ 64, 48)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv3d_3[0][0]    │
# │ (BatchNormalizatio… │ 64, 48)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64, 48)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_1     │ (None, 32, 32,    │          0 │ activation_3[0][… │
# │ (MaxPooling3D)      │ 32, 48)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling3d_1[… │
# │                     │ 32, 48)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_4 (Conv3D)   │ (None, 32, 32,    │    124,512 │ dropout_1[0][0]   │
# │                     │ 32, 96)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        384 │ conv3d_4[0][0]    │
# │ (BatchNormalizatio… │ 32, 96)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32, 96)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_5 (Conv3D)   │ (None, 32, 32,    │    248,928 │ activation_4[0][… │
# │                     │ 32, 96)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        384 │ conv3d_5[0][0]    │
# │ (BatchNormalizatio… │ 32, 96)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32, 96)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_2     │ (None, 16, 16,    │          0 │ activation_5[0][… │
# │ (MaxPooling3D)      │ 16, 96)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling3d_2[… │
# │                     │ 16, 96)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_6 (Conv3D)   │ (None, 16, 16,    │    497,856 │ dropout_2[0][0]   │
# │                     │ 16, 192)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        768 │ conv3d_6[0][0]    │
# │ (BatchNormalizatio… │ 16, 192)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16, 192)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_7 (Conv3D)   │ (None, 16, 16,    │    995,520 │ activation_6[0][… │
# │                     │ 16, 192)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        768 │ conv3d_7[0][0]    │
# │ (BatchNormalizatio… │ 16, 192)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16, 192)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling3d_3     │ (None, 8, 8, 8,   │          0 │ activation_7[0][… │
# │ (MaxPooling3D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 8, 8, 8,   │          0 │ max_pooling3d_3[… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_8 (Conv3D)   │ (None, 8, 8, 8,   │  1,991,040 │ dropout_3[0][0]   │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 8,   │      1,536 │ conv3d_8[0][0]    │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 8, 8, 8,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_9 (Conv3D)   │ (None, 8, 8, 8,   │  3,981,696 │ activation_8[0][… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 8,   │      1,536 │ conv3d_9[0][0]    │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 8, 8, 8,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose    │ (None, 16, 16,    │    590,016 │ activation_9[0][… │
# │ (Conv3DTranspose)   │ 16, 192)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 16, 384)          │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16, 16,    │          0 │ concatenate[0][0] │
# │                     │ 16, 384)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_10 (Conv3D)  │ (None, 16, 16,    │  1,990,848 │ dropout_4[0][0]   │
# │                     │ 16, 192)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        768 │ conv3d_10[0][0]   │
# │ (BatchNormalizatio… │ 16, 192)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16, 192)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_11 (Conv3D)  │ (None, 16, 16,    │    995,520 │ activation_10[0]… │
# │                     │ 16, 192)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        768 │ conv3d_11[0][0]   │
# │ (BatchNormalizatio… │ 16, 192)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16, 192)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_1  │ (None, 32, 32,    │    147,552 │ activation_11[0]… │
# │ (Conv3DTranspose)   │ 32, 96)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 32, 192)          │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 32, 32,    │          0 │ concatenate_1[0]… │
# │                     │ 32, 192)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_12 (Conv3D)  │ (None, 32, 32,    │    497,760 │ dropout_5[0][0]   │
# │                     │ 32, 96)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        384 │ conv3d_12[0][0]   │
# │ (BatchNormalizatio… │ 32, 96)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32, 96)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_13 (Conv3D)  │ (None, 32, 32,    │    248,928 │ activation_12[0]… │
# │                     │ 32, 96)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        384 │ conv3d_13[0][0]   │
# │ (BatchNormalizatio… │ 32, 96)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32, 96)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_2  │ (None, 64, 64,    │     36,912 │ activation_13[0]… │
# │ (Conv3DTranspose)   │ 64, 48)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 64, 96)           │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 64, 64,    │          0 │ concatenate_2[0]… │
# │                     │ 64, 96)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_14 (Conv3D)  │ (None, 64, 64,    │    124,464 │ dropout_6[0][0]   │
# │                     │ 64, 48)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv3d_14[0][0]   │
# │ (BatchNormalizatio… │ 64, 48)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64, 48)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_15 (Conv3D)  │ (None, 64, 64,    │     62,256 │ activation_14[0]… │
# │                     │ 64, 48)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv3d_15[0][0]   │
# │ (BatchNormalizatio… │ 64, 48)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64, 48)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_transpose_3  │ (None, 128, 128,  │      9,240 │ activation_15[0]… │
# │ (Conv3DTranspose)   │ 128, 24)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv3d_transpose… │
# │ (Concatenate)       │ 128, 48)          │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128, 128,  │          0 │ concatenate_3[0]… │
# │                     │ 128, 48)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_16 (Conv3D)  │ (None, 128, 128,  │     31,128 │ dropout_7[0][0]   │
# │                     │ 128, 24)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         96 │ conv3d_16[0][0]   │
# │ (BatchNormalizatio… │ 128, 24)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128, 24)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_17 (Conv3D)  │ (None, 128, 128,  │     15,576 │ activation_16[0]… │
# │                     │ 128, 24)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         96 │ conv3d_17[0][0]   │
# │ (BatchNormalizatio… │ 128, 24)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128, 24)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_18 (Conv3D)  │ (None, 128, 128,  │         75 │ activation_17[0]… │
# │                     │ 128, 3)           │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 12,708,315 (48.48 MB)
#  Trainable params: 12,703,899 (48.46 MB)
#  Non-trainable params: 4,416 (17.25 KB)

# %%
EPOCHS = 60
CHECKPOINT_DIR = 'checkpoints'
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

# Custom callback to track learning rate
class LearningRateLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = float(tf.keras.backend.get_value(self.model.optimizer.learning_rate))
        logs['learning_rate'] = lr

callbacks = [
    # Save best model based on validation tumor dice
    tf.keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(CHECKPOINT_DIR, 'best_model_tumor_dice.keras'),
        monitor='val_dice_tumor',
        mode='max',
        save_best_only=True,
        verbose=1
    ),
    # Save latest checkpoint every epoch
    tf.keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(CHECKPOINT_DIR, 'latest_checkpoint.keras'),
        save_best_only=False,
        verbose=0
    ),
    # Reduce learning rate when val_dice_tumor plateaus
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_dice_tumor',
        mode='max',
        factor=0.5,
        patience=12,
        min_lr=1e-7,
        verbose=1
    ),
    # Early stopping if no improvement
    tf.keras.callbacks.EarlyStopping(
        monitor='val_dice_tumor',
        mode='max',
        patience=25,
        restore_best_weights=True,
        verbose=1
    ),
    # Track learning rate
    LearningRateLogger()
]

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

# Save final model and history
model.save('final_model.keras')
print("\nFinal model saved to final_model.keras")

history_dict = {key: [float(v) for v in values] for key, values in history.history.items()}
with open('training_history.json', 'w') as f:
    json.dump(history_dict, f, indent=2)
print("Training history saved to training_history.json")
# Out:
# /home/xenon/Documents/Python/BME 4790/Project2/venv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2025-12-17 00:53:32.827248: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91700
# Epoch 1/60
# 2025-12-17 00:53:39.135907: I external/local_xla/xla/service/service.cc:163] XLA service 0x78795c058e10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-12-17 00:53:39.135919: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 Laptop GPU, Compute Capability 8.9
# 2025-12-17 00:53:39.268724: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-12-17 00:53:43.724648: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv (bf16[4,24,128,128,128]{4,3,2,1,0}, u8[0]{0}) custom-call(bf16[4,24,128,128,128]{4,3,2,1,0}, bf16[24,24,3,3,3]{4,3,2,1,0}, bf16[24]{0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-17 00:53:43.821623: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.097165803s
# Trying algorithm eng0{} for conv (bf16[4,24,128,128,128]{4,3,2,1,0}, u8[0]{0}) custom-call(bf16[4,24,128,128,128]{4,3,2,1,0}, bf16[24,24,3,3,3]{4,3,2,1,0}, bf16[24]{0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-17 00:53:48.620086: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv (bf16[4,48,64,64,64]{4,3,2,1,0}, u8[0]{0}) custom-call(bf16[4,96,64,64,64]{4,3,2,1,0}, bf16[48,96,3,3,3]{4,3,2,1,0}, bf16[48]{0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-17 00:53:48.644190: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.024200107s
# Trying algorithm eng0{} for conv (bf16[4,48,64,64,64]{4,3,2,1,0}, u8[0]{0}) custom-call(bf16[4,96,64,64,64]{4,3,2,1,0}, bf16[48,96,3,3,3]{4,3,2,1,0}, bf16[48]{0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-17 00:53:53.139255: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv (bf16[4,24,128,128,128]{4,3,2,1,0}, u8[0]{0}) custom-call(bf16[4,48,128,128,128]{4,3,2,1,0}, bf16[24,48,3,3,3]{4,3,2,1,0}, bf16[24]{0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-17 00:53:54.325426: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.186230559s
# Trying algorithm eng0{} for conv (bf16[4,24,128,128,128]{4,3,2,1,0}, u8[0]{0}) custom-call(bf16[4,48,128,128,128]{4,3,2,1,0}, bf16[24,48,3,3,3]{4,3,2,1,0}, bf16[24]{0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-17 00:53:58.455986: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng25{k2=1,k3=0} for conv (bf16[4,24,128,128,128]{4,3,2,1,0}, u8[0]{0}) custom-call(bf16[4,24,128,128,128]{4,3,2,1,0}, bf16[24,24,3,3,3]{4,3,2,1,0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-17 00:53:58.493111: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.037188417s
# Trying algorithm eng25{k2=1,k3=0} for conv (bf16[4,24,128,128,128]{4,3,2,1,0}, u8[0]{0}) custom-call(bf16[4,24,128,128,128]{4,3,2,1,0}, bf16[24,24,3,3,3]{4,3,2,1,0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-17 00:54:03.161500: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng25{k2=1,k3=0} for conv (bf16[4,48,128,128,128]{4,3,2,1,0}, u8[0]{0}) custom-call(bf16[4,24,128,128,128]{4,3,2,1,0}, bf16[24,48,3,3,3]{4,3,2,1,0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-17 00:54:03.767875: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.606534584s
# Trying algorithm eng25{k2=1,k3=0} for conv (bf16[4,48,128,128,128]{4,3,2,1,0}, u8[0]{0}) custom-call(bf16[4,24,128,128,128]{4,3,2,1,0}, bf16[24,48,3,3,3]{4,3,2,1,0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-17 00:54:04.768095: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv (bf16[4,48,128,128,128]{4,3,2,1,0}, u8[0]{0}) custom-call(bf16[4,24,128,128,128]{4,3,2,1,0}, bf16[24,48,3,3,3]{4,3,2,1,0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-17 00:54:05.679623: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.911691963s
# Trying algorithm eng0{} for conv (bf16[4,48,128,128,128]{4,3,2,1,0}, u8[0]{0}) custom-call(bf16[4,24,128,128,128]{4,3,2,1,0}, bf16[24,48,3,3,3]{4,3,2,1,0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-17 00:54:23.319793: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv (bf16[48,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(bf16[4,96,64,64,64]{4,3,2,1,0}, bf16[4,48,64,64,64]{4,3,2,1,0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-17 00:54:24.090095: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.770384648s
# Trying algorithm eng0{} for conv (bf16[48,96,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(bf16[4,96,64,64,64]{4,3,2,1,0}, bf16[4,48,64,64,64]{4,3,2,1,0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-17 00:54:28.481740: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv (bf16[24,48,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(bf16[4,48,128,128,128]{4,3,2,1,0}, bf16[4,24,128,128,128]{4,3,2,1,0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-17 00:54:31.345429: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 3.863752817s
# Trying algorithm eng0{} for conv (bf16[24,48,3,3,3]{4,3,2,1,0}, u8[0]{0}) custom-call(bf16[4,48,128,128,128]{4,3,2,1,0}, bf16[4,24,128,128,128]{4,3,2,1,0}), window={size=3x3x3 pad=1_1x1_1x1_1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# I0000 00:00:1765950879.178880    6547 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 931ms/step - dice_coefficient: 0.9193 - dice_liver: 0.8098 - dice_tumor: 0.5211 - loss: 0.4658
# Epoch 1: val_dice_tumor improved from None to 0.42323, saving model to checkpoints/best_model_tumor_dice.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 514s 988ms/step - dice_coefficient: 0.9208 - dice_liver: 0.8170 - dice_tumor: 0.5186 - loss: 0.4679 - val_dice_coefficient: 0.9463 - val_dice_liver: 0.8686 - val_dice_tumor: 0.4232 - val_loss: 0.5571 - learning_rate: 1.0000e-04
# Epoch 2/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 945ms/step - dice_coefficient: 0.9256 - dice_liver: 0.8199 - dice_tumor: 0.4986 - loss: 0.4870
# Epoch 2: val_dice_tumor did not improve from 0.42323
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 454s 997ms/step - dice_coefficient: 0.9227 - dice_liver: 0.8201 - dice_tumor: 0.5047 - loss: 0.4811 - val_dice_coefficient: 0.9369 - val_dice_liver: 0.8604 - val_dice_tumor: 0.4018 - val_loss: 0.5780 - learning_rate: 1.0000e-04
# Epoch 3/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 940ms/step - dice_coefficient: 0.9225 - dice_liver: 0.8257 - dice_tumor: 0.5387 - loss: 0.4483
# Epoch 3: val_dice_tumor improved from 0.42323 to 0.43984, saving model to checkpoints/best_model_tumor_dice.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 452s 993ms/step - dice_coefficient: 0.9231 - dice_liver: 0.8213 - dice_tumor: 0.5233 - loss: 0.4632 - val_dice_coefficient: 0.9480 - val_dice_liver: 0.8761 - val_dice_tumor: 0.4398 - val_loss: 0.5409 - learning_rate: 1.0000e-04
# Epoch 4/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 937ms/step - dice_coefficient: 0.9231 - dice_liver: 0.8247 - dice_tumor: 0.5455 - loss: 0.4419
# Epoch 4: val_dice_tumor did not improve from 0.43984
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 449s 988ms/step - dice_coefficient: 0.9212 - dice_liver: 0.8172 - dice_tumor: 0.5208 - loss: 0.4658 - val_dice_coefficient: 0.9335 - val_dice_liver: 0.8528 - val_dice_tumor: 0.3412 - val_loss: 0.6363 - learning_rate: 1.0000e-04
# Epoch 5/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 917ms/step - dice_coefficient: 0.9252 - dice_liver: 0.8320 - dice_tumor: 0.5106 - loss: 0.4750
# Epoch 5: val_dice_tumor did not improve from 0.43984
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 441s 969ms/step - dice_coefficient: 0.9226 - dice_liver: 0.8206 - dice_tumor: 0.5095 - loss: 0.4764 - val_dice_coefficient: 0.9476 - val_dice_liver: 0.8756 - val_dice_tumor: 0.4060 - val_loss: 0.5733 - learning_rate: 1.0000e-04
# Epoch 6/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 926ms/step - dice_coefficient: 0.9227 - dice_liver: 0.8324 - dice_tumor: 0.5334 - loss: 0.4531
# Epoch 6: val_dice_tumor did not improve from 0.43984
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 445s 977ms/step - dice_coefficient: 0.9262 - dice_liver: 0.8299 - dice_tumor: 0.5363 - loss: 0.4505 - val_dice_coefficient: 0.9473 - val_dice_liver: 0.8699 - val_dice_tumor: 0.3780 - val_loss: 0.6003 - learning_rate: 1.0000e-04
# Epoch 7/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 937ms/step - dice_coefficient: 0.9268 - dice_liver: 0.8319 - dice_tumor: 0.5607 - loss: 0.4271
# Epoch 7: val_dice_tumor improved from 0.43984 to 0.45492, saving model to checkpoints/best_model_tumor_dice.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 450s 989ms/step - dice_coefficient: 0.9266 - dice_liver: 0.8279 - dice_tumor: 0.5554 - loss: 0.4323 - val_dice_coefficient: 0.9549 - val_dice_liver: 0.8901 - val_dice_tumor: 0.4549 - val_loss: 0.5260 - learning_rate: 1.0000e-04
# Epoch 8/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 935ms/step - dice_coefficient: 0.9251 - dice_liver: 0.8252 - dice_tumor: 0.5437 - loss: 0.4436
# Epoch 8: val_dice_tumor did not improve from 0.45492
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 449s 987ms/step - dice_coefficient: 0.9274 - dice_liver: 0.8292 - dice_tumor: 0.5444 - loss: 0.4427 - val_dice_coefficient: 0.9417 - val_dice_liver: 0.8597 - val_dice_tumor: 0.3425 - val_loss: 0.6347 - learning_rate: 1.0000e-04
# Epoch 9/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 944ms/step - dice_coefficient: 0.9256 - dice_liver: 0.8242 - dice_tumor: 0.5387 - loss: 0.4484
# Epoch 9: val_dice_tumor did not improve from 0.45492
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 453s 996ms/step - dice_coefficient: 0.9220 - dice_liver: 0.8205 - dice_tumor: 0.5125 - loss: 0.4736 - val_dice_coefficient: 0.9464 - val_dice_liver: 0.8753 - val_dice_tumor: 0.4096 - val_loss: 0.5699 - learning_rate: 1.0000e-04
# Epoch 10/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 949ms/step - dice_coefficient: 0.9281 - dice_liver: 0.8339 - dice_tumor: 0.5194 - loss: 0.4665
# Epoch 10: val_dice_tumor did not improve from 0.45492
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 456s 1s/step - dice_coefficient: 0.9284 - dice_liver: 0.8300 - dice_tumor: 0.5362 - loss: 0.4505 - val_dice_coefficient: 0.9477 - val_dice_liver: 0.8762 - val_dice_tumor: 0.4075 - val_loss: 0.5719 - learning_rate: 1.0000e-04
# Epoch 11/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 904ms/step - dice_coefficient: 0.9259 - dice_liver: 0.8215 - dice_tumor: 0.5250 - loss: 0.4616
# Epoch 11: val_dice_tumor did not improve from 0.45492
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 435s 956ms/step - dice_coefficient: 0.9254 - dice_liver: 0.8289 - dice_tumor: 0.5363 - loss: 0.4505 - val_dice_coefficient: 0.9405 - val_dice_liver: 0.8621 - val_dice_tumor: 0.4284 - val_loss: 0.5525 - learning_rate: 1.0000e-04
# Epoch 12/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 931ms/step - dice_coefficient: 0.9294 - dice_liver: 0.8349 - dice_tumor: 0.5626 - loss: 0.4251
# Epoch 12: val_dice_tumor did not improve from 0.45492
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 448s 984ms/step - dice_coefficient: 0.9296 - dice_liver: 0.8353 - dice_tumor: 0.5533 - loss: 0.4339 - val_dice_coefficient: 0.9473 - val_dice_liver: 0.8755 - val_dice_tumor: 0.4074 - val_loss: 0.5720 - learning_rate: 1.0000e-04
# Epoch 13/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 933ms/step - dice_coefficient: 0.9288 - dice_liver: 0.8434 - dice_tumor: 0.5614 - loss: 0.4259
# Epoch 13: val_dice_tumor did not improve from 0.45492
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 448s 985ms/step - dice_coefficient: 0.9310 - dice_liver: 0.8378 - dice_tumor: 0.5447 - loss: 0.4421 - val_dice_coefficient: 0.9539 - val_dice_liver: 0.8886 - val_dice_tumor: 0.4235 - val_loss: 0.5561 - learning_rate: 1.0000e-04
# Epoch 14/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 916ms/step - dice_coefficient: 0.9297 - dice_liver: 0.8352 - dice_tumor: 0.5449 - loss: 0.4420
# Epoch 14: val_dice_tumor did not improve from 0.45492
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 440s 968ms/step - dice_coefficient: 0.9295 - dice_liver: 0.8353 - dice_tumor: 0.5465 - loss: 0.4405 - val_dice_coefficient: 0.9366 - val_dice_liver: 0.8558 - val_dice_tumor: 0.4033 - val_loss: 0.5767 - learning_rate: 1.0000e-04
# Epoch 15/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 930ms/step - dice_coefficient: 0.9236 - dice_liver: 0.8243 - dice_tumor: 0.5240 - loss: 0.4625
# Epoch 15: val_dice_tumor did not improve from 0.45492
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 447s 981ms/step - dice_coefficient: 0.9279 - dice_liver: 0.8336 - dice_tumor: 0.5436 - loss: 0.4434 - val_dice_coefficient: 0.9530 - val_dice_liver: 0.8845 - val_dice_tumor: 0.4274 - val_loss: 0.5525 - learning_rate: 1.0000e-04
# Epoch 16/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 925ms/step - dice_coefficient: 0.9294 - dice_liver: 0.8437 - dice_tumor: 0.5618 - loss: 0.4255
# Epoch 16: val_dice_tumor did not improve from 0.45492
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 445s 977ms/step - dice_coefficient: 0.9330 - dice_liver: 0.8401 - dice_tumor: 0.5700 - loss: 0.4178 - val_dice_coefficient: 0.9497 - val_dice_liver: 0.8766 - val_dice_tumor: 0.4135 - val_loss: 0.5661 - learning_rate: 1.0000e-04
# Epoch 17/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 941ms/step - dice_coefficient: 0.9353 - dice_liver: 0.8452 - dice_tumor: 0.5535 - loss: 0.4334
# Epoch 17: val_dice_tumor did not improve from 0.45492
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 452s 993ms/step - dice_coefficient: 0.9334 - dice_liver: 0.8433 - dice_tumor: 0.5565 - loss: 0.4306 - val_dice_coefficient: 0.9598 - val_dice_liver: 0.9002 - val_dice_tumor: 0.4397 - val_loss: 0.5402 - learning_rate: 1.0000e-04
# Epoch 18/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 921ms/step - dice_coefficient: 0.9317 - dice_liver: 0.8408 - dice_tumor: 0.5454 - loss: 0.4414
# Epoch 18: val_dice_tumor did not improve from 0.45492
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 443s 973ms/step - dice_coefficient: 0.9310 - dice_liver: 0.8394 - dice_tumor: 0.5567 - loss: 0.4306 - val_dice_coefficient: 0.9530 - val_dice_liver: 0.8829 - val_dice_tumor: 0.4271 - val_loss: 0.5529 - learning_rate: 1.0000e-04
# Epoch 19/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 927ms/step - dice_coefficient: 0.9335 - dice_liver: 0.8421 - dice_tumor: 0.5630 - loss: 0.4245
# Epoch 19: val_dice_tumor did not improve from 0.45492
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 446s 979ms/step - dice_coefficient: 0.9337 - dice_liver: 0.8428 - dice_tumor: 0.5731 - loss: 0.4147 - val_dice_coefficient: 0.8877 - val_dice_liver: 0.7257 - val_dice_tumor: 0.2867 - val_loss: 0.6934 - learning_rate: 5.0000e-05
# Epoch 20/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 942ms/step - dice_coefficient: 0.9359 - dice_liver: 0.8489 - dice_tumor: 0.5947 - loss: 0.3938
# Epoch 20: val_dice_tumor improved from 0.45492 to 0.47291, saving model to checkpoints/best_model_tumor_dice.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 452s 995ms/step - dice_coefficient: 0.9336 - dice_liver: 0.8411 - dice_tumor: 0.5855 - loss: 0.4029 - val_dice_coefficient: 0.9532 - val_dice_liver: 0.8867 - val_dice_tumor: 0.4729 - val_loss: 0.5089 - learning_rate: 5.0000e-05
# Epoch 21/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 927ms/step - dice_coefficient: 0.9371 - dice_liver: 0.8485 - dice_tumor: 0.5828 - loss: 0.4053
# Epoch 21: val_dice_tumor did not improve from 0.47291
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 446s 979ms/step - dice_coefficient: 0.9356 - dice_liver: 0.8463 - dice_tumor: 0.5910 - loss: 0.3974 - val_dice_coefficient: 0.9555 - val_dice_liver: 0.8916 - val_dice_tumor: 0.4560 - val_loss: 0.5249 - learning_rate: 5.0000e-05
# Epoch 22/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 926ms/step - dice_coefficient: 0.9325 - dice_liver: 0.8432 - dice_tumor: 0.6245 - loss: 0.3655
# Epoch 22: val_dice_tumor did not improve from 0.47291
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 445s 978ms/step - dice_coefficient: 0.9383 - dice_liver: 0.8509 - dice_tumor: 0.6110 - loss: 0.3781 - val_dice_coefficient: 0.9520 - val_dice_liver: 0.8833 - val_dice_tumor: 0.4359 - val_loss: 0.5444 - learning_rate: 5.0000e-05
# Epoch 23/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 935ms/step - dice_coefficient: 0.9362 - dice_liver: 0.8390 - dice_tumor: 0.6163 - loss: 0.3735
# Epoch 23: val_dice_tumor did not improve from 0.47291
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 449s 987ms/step - dice_coefficient: 0.9379 - dice_liver: 0.8484 - dice_tumor: 0.6125 - loss: 0.3768 - val_dice_coefficient: 0.9538 - val_dice_liver: 0.8866 - val_dice_tumor: 0.4548 - val_loss: 0.5262 - learning_rate: 5.0000e-05
# Epoch 24/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 894ms/step - dice_coefficient: 0.9364 - dice_liver: 0.8550 - dice_tumor: 0.5942 - loss: 0.3940
# Epoch 24: val_dice_tumor did not improve from 0.47291
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 430s 946ms/step - dice_coefficient: 0.9365 - dice_liver: 0.8476 - dice_tumor: 0.6124 - loss: 0.3770 - val_dice_coefficient: 0.9615 - val_dice_liver: 0.9021 - val_dice_tumor: 0.4694 - val_loss: 0.5116 - learning_rate: 5.0000e-05
# Epoch 25/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 915ms/step - dice_coefficient: 0.9375 - dice_liver: 0.8532 - dice_tumor: 0.6342 - loss: 0.3558
# Epoch 25: val_dice_tumor did not improve from 0.47291
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 440s 967ms/step - dice_coefficient: 0.9376 - dice_liver: 0.8501 - dice_tumor: 0.6126 - loss: 0.3766 - val_dice_coefficient: 0.9524 - val_dice_liver: 0.8845 - val_dice_tumor: 0.4390 - val_loss: 0.5414 - learning_rate: 5.0000e-05
# Epoch 26/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 937ms/step - dice_coefficient: 0.9357 - dice_liver: 0.8521 - dice_tumor: 0.6200 - loss: 0.3695
# Epoch 26: val_dice_tumor did not improve from 0.47291
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 450s 989ms/step - dice_coefficient: 0.9373 - dice_liver: 0.8488 - dice_tumor: 0.6082 - loss: 0.3810 - val_dice_coefficient: 0.9558 - val_dice_liver: 0.8936 - val_dice_tumor: 0.4570 - val_loss: 0.5238 - learning_rate: 5.0000e-05
# Epoch 27/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 931ms/step - dice_coefficient: 0.9393 - dice_liver: 0.8482 - dice_tumor: 0.5972 - loss: 0.3915
# Epoch 27: val_dice_tumor did not improve from 0.47291
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 448s 983ms/step - dice_coefficient: 0.9381 - dice_liver: 0.8500 - dice_tumor: 0.6063 - loss: 0.3827 - val_dice_coefficient: 0.9556 - val_dice_liver: 0.8872 - val_dice_tumor: 0.3986 - val_loss: 0.5799 - learning_rate: 5.0000e-05
# Epoch 28/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 907ms/step - dice_coefficient: 0.9366 - dice_liver: 0.8470 - dice_tumor: 0.5962 - loss: 0.3925
# Epoch 28: val_dice_tumor did not improve from 0.47291
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 437s 959ms/step - dice_coefficient: 0.9387 - dice_liver: 0.8525 - dice_tumor: 0.6228 - loss: 0.3668 - val_dice_coefficient: 0.9534 - val_dice_liver: 0.8913 - val_dice_tumor: 0.4144 - val_loss: 0.5647 - learning_rate: 5.0000e-05
# Epoch 29/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 922ms/step - dice_coefficient: 0.9419 - dice_liver: 0.8531 - dice_tumor: 0.6151 - loss: 0.3741
# Epoch 29: val_dice_tumor did not improve from 0.47291
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 443s 973ms/step - dice_coefficient: 0.9396 - dice_liver: 0.8538 - dice_tumor: 0.6179 - loss: 0.3714 - val_dice_coefficient: 0.9532 - val_dice_liver: 0.8873 - val_dice_tumor: 0.4309 - val_loss: 0.5490 - learning_rate: 5.0000e-05
# Epoch 30/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 915ms/step - dice_coefficient: 0.9393 - dice_liver: 0.8553 - dice_tumor: 0.6136 - loss: 0.3755
# Epoch 30: val_dice_tumor did not improve from 0.47291
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 441s 967ms/step - dice_coefficient: 0.9397 - dice_liver: 0.8531 - dice_tumor: 0.6168 - loss: 0.3725 - val_dice_coefficient: 0.9602 - val_dice_liver: 0.9010 - val_dice_tumor: 0.4673 - val_loss: 0.5137 - learning_rate: 5.0000e-05
# Epoch 31/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 939ms/step - dice_coefficient: 0.9364 - dice_liver: 0.8532 - dice_tumor: 0.6109 - loss: 0.3781
# Epoch 31: val_dice_tumor improved from 0.47291 to 0.48122, saving model to checkpoints/best_model_tumor_dice.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 451s 992ms/step - dice_coefficient: 0.9382 - dice_liver: 0.8503 - dice_tumor: 0.6143 - loss: 0.3750 - val_dice_coefficient: 0.9579 - val_dice_liver: 0.8968 - val_dice_tumor: 0.4812 - val_loss: 0.5005 - learning_rate: 5.0000e-05
# Epoch 32/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 923ms/step - dice_coefficient: 0.9400 - dice_liver: 0.8584 - dice_tumor: 0.6457 - loss: 0.3447
# Epoch 32: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 445s 977ms/step - dice_coefficient: 0.9407 - dice_liver: 0.8571 - dice_tumor: 0.6202 - loss: 0.3691 - val_dice_coefficient: 0.9586 - val_dice_liver: 0.9013 - val_dice_tumor: 0.4525 - val_loss: 0.5278 - learning_rate: 5.0000e-05
# Epoch 33/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 928ms/step - dice_coefficient: 0.9404 - dice_liver: 0.8538 - dice_tumor: 0.6459 - loss: 0.3446
# Epoch 33: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 446s 981ms/step - dice_coefficient: 0.9412 - dice_liver: 0.8572 - dice_tumor: 0.6250 - loss: 0.3645 - val_dice_coefficient: 0.9658 - val_dice_liver: 0.9109 - val_dice_tumor: 0.4795 - val_loss: 0.5016 - learning_rate: 5.0000e-05
# Epoch 34/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 940ms/step - dice_coefficient: 0.9360 - dice_liver: 0.8504 - dice_tumor: 0.6144 - loss: 0.3749
# Epoch 34: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 452s 992ms/step - dice_coefficient: 0.9395 - dice_liver: 0.8532 - dice_tumor: 0.6160 - loss: 0.3733 - val_dice_coefficient: 0.9617 - val_dice_liver: 0.9045 - val_dice_tumor: 0.4365 - val_loss: 0.5430 - learning_rate: 5.0000e-05
# Epoch 35/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 933ms/step - dice_coefficient: 0.9407 - dice_liver: 0.8511 - dice_tumor: 0.6272 - loss: 0.3626
# Epoch 35: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 448s 985ms/step - dice_coefficient: 0.9418 - dice_liver: 0.8578 - dice_tumor: 0.6190 - loss: 0.3702 - val_dice_coefficient: 0.9437 - val_dice_liver: 0.8722 - val_dice_tumor: 0.4164 - val_loss: 0.5635 - learning_rate: 5.0000e-05
# Epoch 36/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 926ms/step - dice_coefficient: 0.9415 - dice_liver: 0.8578 - dice_tumor: 0.6097 - loss: 0.3791
# Epoch 36: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 445s 978ms/step - dice_coefficient: 0.9420 - dice_liver: 0.8599 - dice_tumor: 0.6265 - loss: 0.3630 - val_dice_coefficient: 0.9629 - val_dice_liver: 0.9061 - val_dice_tumor: 0.4573 - val_loss: 0.5230 - learning_rate: 5.0000e-05
# Epoch 37/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 915ms/step - dice_coefficient: 0.9434 - dice_liver: 0.8593 - dice_tumor: 0.6377 - loss: 0.3522
# Epoch 37: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 440s 967ms/step - dice_coefficient: 0.9426 - dice_liver: 0.8612 - dice_tumor: 0.6275 - loss: 0.3619 - val_dice_coefficient: 0.9571 - val_dice_liver: 0.8989 - val_dice_tumor: 0.4586 - val_loss: 0.5221 - learning_rate: 5.0000e-05
# Epoch 38/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 926ms/step - dice_coefficient: 0.9428 - dice_liver: 0.8514 - dice_tumor: 0.6052 - loss: 0.3836
# Epoch 38: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 445s 979ms/step - dice_coefficient: 0.9415 - dice_liver: 0.8593 - dice_tumor: 0.6269 - loss: 0.3626 - val_dice_coefficient: 0.9615 - val_dice_liver: 0.9037 - val_dice_tumor: 0.4660 - val_loss: 0.5148 - learning_rate: 5.0000e-05
# Epoch 39/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 937ms/step - dice_coefficient: 0.9448 - dice_liver: 0.8629 - dice_tumor: 0.6055 - loss: 0.3830
# Epoch 39: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 450s 989ms/step - dice_coefficient: 0.9432 - dice_liver: 0.8619 - dice_tumor: 0.6289 - loss: 0.3606 - val_dice_coefficient: 0.9641 - val_dice_liver: 0.9058 - val_dice_tumor: 0.4130 - val_loss: 0.5654 - learning_rate: 5.0000e-05
# Epoch 40/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 927ms/step - dice_coefficient: 0.9415 - dice_liver: 0.8532 - dice_tumor: 0.6312 - loss: 0.3587
# Epoch 40: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 446s 978ms/step - dice_coefficient: 0.9428 - dice_liver: 0.8610 - dice_tumor: 0.6350 - loss: 0.3548 - val_dice_coefficient: 0.9629 - val_dice_liver: 0.9047 - val_dice_tumor: 0.4487 - val_loss: 0.5313 - learning_rate: 5.0000e-05
# Epoch 41/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 935ms/step - dice_coefficient: 0.9436 - dice_liver: 0.8547 - dice_tumor: 0.6539 - loss: 0.3369
# Epoch 41: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 450s 988ms/step - dice_coefficient: 0.9443 - dice_liver: 0.8622 - dice_tumor: 0.6392 - loss: 0.3507 - val_dice_coefficient: 0.9659 - val_dice_liver: 0.9113 - val_dice_tumor: 0.4442 - val_loss: 0.5353 - learning_rate: 5.0000e-05
# Epoch 42/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 924ms/step - dice_coefficient: 0.9438 - dice_liver: 0.8645 - dice_tumor: 0.6252 - loss: 0.3640
# Epoch 42: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 444s 976ms/step - dice_coefficient: 0.9435 - dice_liver: 0.8615 - dice_tumor: 0.6256 - loss: 0.3638 - val_dice_coefficient: 0.9631 - val_dice_liver: 0.9060 - val_dice_tumor: 0.4617 - val_loss: 0.5189 - learning_rate: 5.0000e-05
# Epoch 43/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 918ms/step - dice_coefficient: 0.9394 - dice_liver: 0.8525 - dice_tumor: 0.6273 - loss: 0.3625
# Epoch 43: val_dice_tumor did not improve from 0.48122
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 442s 970ms/step - dice_coefficient: 0.9433 - dice_liver: 0.8607 - dice_tumor: 0.6336 - loss: 0.3561 - val_dice_coefficient: 0.9597 - val_dice_liver: 0.9028 - val_dice_tumor: 0.4596 - val_loss: 0.5210 - learning_rate: 2.5000e-05
# Epoch 44/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 931ms/step - dice_coefficient: 0.9441 - dice_liver: 0.8601 - dice_tumor: 0.6353 - loss: 0.3545
# Epoch 44: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 447s 982ms/step - dice_coefficient: 0.9451 - dice_liver: 0.8651 - dice_tumor: 0.6391 - loss: 0.3507 - val_dice_coefficient: 0.9625 - val_dice_liver: 0.9069 - val_dice_tumor: 0.4629 - val_loss: 0.5177 - learning_rate: 2.5000e-05
# Epoch 45/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 923ms/step - dice_coefficient: 0.9452 - dice_liver: 0.8599 - dice_tumor: 0.6253 - loss: 0.3641
# Epoch 45: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 444s 975ms/step - dice_coefficient: 0.9459 - dice_liver: 0.8667 - dice_tumor: 0.6483 - loss: 0.3418 - val_dice_coefficient: 0.9693 - val_dice_liver: 0.9197 - val_dice_tumor: 0.4734 - val_loss: 0.5071 - learning_rate: 2.5000e-05
# Epoch 46/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 922ms/step - dice_coefficient: 0.9440 - dice_liver: 0.8578 - dice_tumor: 0.6474 - loss: 0.3430
# Epoch 46: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 443s 973ms/step - dice_coefficient: 0.9462 - dice_liver: 0.8673 - dice_tumor: 0.6539 - loss: 0.3364 - val_dice_coefficient: 0.9685 - val_dice_liver: 0.9179 - val_dice_tumor: 0.4696 - val_loss: 0.5108 - learning_rate: 2.5000e-05
# Epoch 47/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 941ms/step - dice_coefficient: 0.9473 - dice_liver: 0.8647 - dice_tumor: 0.6512 - loss: 0.3391
# Epoch 47: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 452s 993ms/step - dice_coefficient: 0.9473 - dice_liver: 0.8697 - dice_tumor: 0.6485 - loss: 0.3415 - val_dice_coefficient: 0.9675 - val_dice_liver: 0.9155 - val_dice_tumor: 0.4467 - val_loss: 0.5328 - learning_rate: 2.5000e-05
# Epoch 48/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 925ms/step - dice_coefficient: 0.9453 - dice_liver: 0.8684 - dice_tumor: 0.6451 - loss: 0.3448
# Epoch 48: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 444s 976ms/step - dice_coefficient: 0.9476 - dice_liver: 0.8688 - dice_tumor: 0.6455 - loss: 0.3444 - val_dice_coefficient: 0.9656 - val_dice_liver: 0.9125 - val_dice_tumor: 0.4653 - val_loss: 0.5151 - learning_rate: 2.5000e-05
# Epoch 49/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 938ms/step - dice_coefficient: 0.9463 - dice_liver: 0.8687 - dice_tumor: 0.6499 - loss: 0.3402
# Epoch 49: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 451s 991ms/step - dice_coefficient: 0.9467 - dice_liver: 0.8678 - dice_tumor: 0.6563 - loss: 0.3341 - val_dice_coefficient: 0.9649 - val_dice_liver: 0.9120 - val_dice_tumor: 0.4671 - val_loss: 0.5134 - learning_rate: 2.5000e-05
# Epoch 50/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 913ms/step - dice_coefficient: 0.9510 - dice_liver: 0.8804 - dice_tumor: 0.6533 - loss: 0.3365
# Epoch 50: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 440s 965ms/step - dice_coefficient: 0.9472 - dice_liver: 0.8699 - dice_tumor: 0.6455 - loss: 0.3443 - val_dice_coefficient: 0.9630 - val_dice_liver: 0.9061 - val_dice_tumor: 0.4797 - val_loss: 0.5016 - learning_rate: 2.5000e-05
# Epoch 51/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 900ms/step - dice_coefficient: 0.9513 - dice_liver: 0.8777 - dice_tumor: 0.6328 - loss: 0.3562
# Epoch 51: val_dice_tumor did not improve from 0.48122
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 433s 952ms/step - dice_coefficient: 0.9481 - dice_liver: 0.8714 - dice_tumor: 0.6477 - loss: 0.3422 - val_dice_coefficient: 0.9686 - val_dice_liver: 0.9162 - val_dice_tumor: 0.4375 - val_loss: 0.5416 - learning_rate: 2.5000e-05
# Epoch 52/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 942ms/step - dice_coefficient: 0.9463 - dice_liver: 0.8625 - dice_tumor: 0.6209 - loss: 0.3682
# Epoch 52: val_dice_tumor improved from 0.48122 to 0.48494, saving model to checkpoints/best_model_tumor_dice.keras
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 453s 994ms/step - dice_coefficient: 0.9474 - dice_liver: 0.8689 - dice_tumor: 0.6500 - loss: 0.3401 - val_dice_coefficient: 0.9664 - val_dice_liver: 0.9127 - val_dice_tumor: 0.4849 - val_loss: 0.4963 - learning_rate: 2.5000e-05
# Epoch 53/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 929ms/step - dice_coefficient: 0.9467 - dice_liver: 0.8695 - dice_tumor: 0.6455 - loss: 0.3444
# Epoch 53: val_dice_tumor did not improve from 0.48494
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 447s 981ms/step - dice_coefficient: 0.9470 - dice_liver: 0.8690 - dice_tumor: 0.6512 - loss: 0.3390 - val_dice_coefficient: 0.9667 - val_dice_liver: 0.9141 - val_dice_tumor: 0.4457 - val_loss: 0.5338 - learning_rate: 2.5000e-05
# Epoch 54/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 926ms/step - dice_coefficient: 0.9455 - dice_liver: 0.8630 - dice_tumor: 0.6761 - loss: 0.3154
# Epoch 54: val_dice_tumor did not improve from 0.48494
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 445s 978ms/step - dice_coefficient: 0.9470 - dice_liver: 0.8700 - dice_tumor: 0.6531 - loss: 0.3371 - val_dice_coefficient: 0.9656 - val_dice_liver: 0.9108 - val_dice_tumor: 0.4796 - val_loss: 0.5015 - learning_rate: 2.5000e-05
# Epoch 55/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 928ms/step - dice_coefficient: 0.9494 - dice_liver: 0.8623 - dice_tumor: 0.6513 - loss: 0.3392
# Epoch 55: val_dice_tumor did not improve from 0.48494
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 446s 980ms/step - dice_coefficient: 0.9480 - dice_liver: 0.8698 - dice_tumor: 0.6578 - loss: 0.3326 - val_dice_coefficient: 0.9666 - val_dice_liver: 0.9126 - val_dice_tumor: 0.4505 - val_loss: 0.5293 - learning_rate: 2.5000e-05
# Epoch 56/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 946ms/step - dice_coefficient: 0.9473 - dice_liver: 0.8677 - dice_tumor: 0.6495 - loss: 0.3406
# Epoch 56: val_dice_tumor did not improve from 0.48494
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 454s 998ms/step - dice_coefficient: 0.9473 - dice_liver: 0.8666 - dice_tumor: 0.6574 - loss: 0.3331 - val_dice_coefficient: 0.9681 - val_dice_liver: 0.9174 - val_dice_tumor: 0.4554 - val_loss: 0.5244 - learning_rate: 2.5000e-05
# Epoch 57/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 933ms/step - dice_coefficient: 0.9504 - dice_liver: 0.8665 - dice_tumor: 0.6502 - loss: 0.3400
# Epoch 57: val_dice_tumor did not improve from 0.48494
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 449s 986ms/step - dice_coefficient: 0.9492 - dice_liver: 0.8722 - dice_tumor: 0.6604 - loss: 0.3300 - val_dice_coefficient: 0.9693 - val_dice_liver: 0.9192 - val_dice_tumor: 0.4481 - val_loss: 0.5314 - learning_rate: 2.5000e-05
# Epoch 58/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 920ms/step - dice_coefficient: 0.9510 - dice_liver: 0.8800 - dice_tumor: 0.6571 - loss: 0.3329
# Epoch 58: val_dice_tumor did not improve from 0.48494
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 443s 972ms/step - dice_coefficient: 0.9482 - dice_liver: 0.8701 - dice_tumor: 0.6466 - loss: 0.3433 - val_dice_coefficient: 0.9661 - val_dice_liver: 0.9145 - val_dice_tumor: 0.4634 - val_loss: 0.5168 - learning_rate: 2.5000e-05
# Epoch 59/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 920ms/step - dice_coefficient: 0.9489 - dice_liver: 0.8807 - dice_tumor: 0.6585 - loss: 0.3315
# Epoch 59: val_dice_tumor did not improve from 0.48494
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 443s 973ms/step - dice_coefficient: 0.9492 - dice_liver: 0.8731 - dice_tumor: 0.6568 - loss: 0.3335 - val_dice_coefficient: 0.9691 - val_dice_liver: 0.9202 - val_dice_tumor: 0.4729 - val_loss: 0.5076 - learning_rate: 2.5000e-05
# Epoch 60/60
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 0s 949ms/step - dice_coefficient: 0.9511 - dice_liver: 0.8683 - dice_tumor: 0.6546 - loss: 0.3357
# Epoch 60: val_dice_tumor did not improve from 0.48494
# 455/455 ━━━━━━━━━━━━━━━━━━━━ 456s 1s/step - dice_coefficient: 0.9487 - dice_liver: 0.8714 - dice_tumor: 0.6565 - loss: 0.3338 - val_dice_coefficient: 0.9669 - val_dice_liver: 0.9162 - val_dice_tumor: 0.4597 - val_loss: 0.5204 - learning_rate: 2.5000e-05
# Restoring model weights from the end of the best epoch: 52.
#
# Final model saved to final_model.keras
# Training history saved to training_history.json

# %%
# Plot training history
with open('training_history.json', 'r') as f:
    history_data = json.load(f)

epochs_range = range(1, len(history_data['loss']) + 1)

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Plot 1: Loss
axes[0, 0].plot(epochs_range, history_data['loss'], 'b-', label='Train Loss')
axes[0, 0].plot(epochs_range, history_data['val_loss'], 'r-', label='Val Loss')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].set_title('Training vs Validation Loss')
axes[0, 0].legend()
axes[0, 0].grid(True)

# Plot 2: Tumor Dice (most important)
axes[0, 1].plot(epochs_range, history_data['dice_tumor'], 'b-', label='Train Tumor Dice')
axes[0, 1].plot(epochs_range, history_data['val_dice_tumor'], 'r-', label='Val Tumor Dice')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Dice Score')
axes[0, 1].set_title('Tumor Dice Score (Primary Metric)')
axes[0, 1].legend()
axes[0, 1].grid(True)

# Plot 3: Liver Dice
axes[1, 0].plot(epochs_range, history_data['dice_liver'], 'b-', label='Train Liver Dice')
axes[1, 0].plot(epochs_range, history_data['val_dice_liver'], 'r-', label='Val Liver Dice')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('Dice Score')
axes[1, 0].set_title('Liver Dice Score')
axes[1, 0].legend()
axes[1, 0].grid(True)

# Plot 4: Learning Rate
if 'learning_rate' in history_data:
    axes[1, 1].plot(epochs_range, history_data['learning_rate'], 'g-', marker='o', markersize=3)
    axes[1, 1].set_xlabel('Epoch')
    axes[1, 1].set_ylabel('Learning Rate')
    axes[1, 1].set_title('Learning Rate Schedule')
    axes[1, 1].set_yscale('log')
    axes[1, 1].grid(True)
else:
    axes[1, 1].text(0.5, 0.5, 'No LR data', ha='center', va='center', transform=axes[1, 1].transAxes)

plt.tight_layout()
plt.savefig('training_curves.png', dpi=150, bbox_inches='tight')
plt.show()

# Print best metrics
best_val_tumor_idx = np.argmax(history_data['val_dice_tumor'])
print(f"\nBest Validation Tumor Dice: {history_data['val_dice_tumor'][best_val_tumor_idx]:.4f} at epoch {best_val_tumor_idx + 1}")
print(f"  - Train Tumor Dice: {history_data['dice_tumor'][best_val_tumor_idx]:.4f}")
print(f"  - Val Liver Dice: {history_data['val_dice_liver'][best_val_tumor_idx]:.4f}")
print(f"  - Val Loss: {history_data['val_loss'][best_val_tumor_idx]:.4f}")
# Out:
# Best Validation Tumor Dice: 0.4849 at epoch 52
#   - Train Tumor Dice: 0.6500
#   - Val Liver Dice: 0.9127
#   - Val Loss: 0.4963
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
